# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'workforce_productivity_marketing.csv')

# %%
df
# Out:
#     employee_id       full_name  age  gender       city  \
# 0      MKT-2001     Komal Reddy   36  Female  Hyderabad
# 1      MKT-2002    Indira Desai   21  Female     Mumbai
# 2      MKT-2003      Amit Mehta   29    Male    Chennai
# 3      MKT-2004    Meera Pandey   30  Female       Pune
# 4      MKT-2005     Tarun Patil   25    Male  Hyderabad
# ..          ...             ...  ...     ...        ...
# 295    MKT-2296     Ananya Bhat   48  Female       Pune
# 296    MKT-2297       Zara Bose   44  Female  Ahmedabad
# 297    MKT-2298    Piyush Menon   52    Male       Pune
# 298    MKT-2299  Sonal Banerjee   34  Female    Chennai
# 299    MKT-2300   Natasha Sethi   43  Female     Jaipur
#
#                    education           certification  \
# 0            MBA (Marketing)              Google Ads
# 1            BA (Journalism)          Meta Blueprint
# 2                        BBA             SEMrush SEO
# 3                      M.Com  Hootsuite Social Media
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 98 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   employee_id                    300 non-null    object
#  1   full_name                      300 non-null    object
#  2   age                            300 non-null    int64
#  3   gender                         300 non-null    object
#  4   city                           300 non-null    object
#  5   education                      300 non-null    object
#  6   certification                  279 non-null    object
#  7   department                     300 non-null    object
#  8   designation                    300 non-null    object
#  9   seniority_level                300 non-null    object
#  10  employment_type                300 non-null    object
#  11  work_mode                      300 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.fillna('NaN',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 98 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   employee_id                    300 non-null    object
#  1   full_name                      300 non-null    object
#  2   age                            300 non-null    int64
#  3   gender                         300 non-null    object
#  4   city                           300 non-null    object
#  5   education                      300 non-null    object
#  6   certification                  300 non-null    object
#  7   department                     300 non-null    object
#  8   designation                    300 non-null    object
#  9   seniority_level                300 non-null    object
#  10  employment_type                300 non-null    object
#  11  work_mode                      300 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'full_name', 'age', 'gender', 'city', 'education',
#        'certification', 'department', 'designation', 'seniority_level',
#        'employment_type', 'work_mode', 'date_of_joining', 'tenure_years',
#        'reporting_to', 'annual_salary_inr', 'task_completion_score',
#        'quality_of_work_score', 'initiative_score', 'collaboration_score',
#        'communication_score', 'problem_solving_score', 'time_management_score',
#        'creativity_score', 'analytical_ability_score',
#        'digital_proficiency_score', 'leadership_score', 'adaptability_score',
#        'customer_focus_score', 'strategic_thinking_score',
#        'self_motivation_score', 'productivity_index', 'performance_rating',
#        'kpi_primary_area', 'kpi_target', 'kpi_achieved', 'kpi_achievement_pct',
#        'campaigns_handled', 'leads_generated', 'conversion_rate_pct',
#        'revenue_contribution_lakh', 'client_satisfaction_score',
# ...

# %% [markdown]
# Gender Distribution

# %%
df['gender'].value_counts().plot(kind='pie',autopct = '%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
df.groupby('designation')['annual_salary_inr'].mean().sort_values().plot(kind='bar')
plt.title('Average Salary Distribution based on Designation')
plt.show()

# %%
df.groupby('department')['productivity_index'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='department'>

# %%
df.columns
df.groupby('department')['kpi_achievement_pct'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='department'>

# %%
df.groupby('work_mode')['productivity_index'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='work_mode'>

# %%
plt.scatter(df['campaigns_handled'],
            df['revenue_contribution_lakh'])
plt.xlabel('Campaigns')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# Job Satisfaction

# %%
df.groupby('department')['job_satisfaction_score'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='department'>

# %% [markdown]
# Attrition Risk Analysis

# %%
df['attrition_risk'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='attrition_risk'>

# %% [markdown]
# Correlation Analysis

# %%
rating_map = {
    'Needs Improvement': 1,
    'Below Expectations': 2,
    'Meets Expectations': 3,
    'Exceeds Expectations': 4,
    'Outstanding': 5
}

df['performance_rating_num'] = df['performance_rating'].map(rating_map)

# %%
corr_cols = [
    'annual_salary_inr',
    'productivity_index',
    'kpi_achievement_pct',
    'job_satisfaction_score',
    'performance_rating_num'
]

corr_matrix=df[corr_cols].corr()
print(corr_matrix)
# Out:
#                         annual_salary_inr  productivity_index  \
# annual_salary_inr                1.000000            0.714447
# productivity_index               0.714447            1.000000
# kpi_achievement_pct             -0.018616            0.048551
# job_satisfaction_score          -0.021136           -0.015786
# performance_rating_num           0.659982            0.912003
#
#                         kpi_achievement_pct  job_satisfaction_score  \
# annual_salary_inr                 -0.018616               -0.021136
# productivity_index                 0.048551               -0.015786
# kpi_achievement_pct                1.000000               -0.085467
# job_satisfaction_score            -0.085467                1.000000
# performance_rating_num             0.066723                0.011745
#
#                         performance_rating_num
# annual_salary_inr                     0.659982
# productivity_index                    0.912003
# ...

# %%
plt.figure(figsize=(8,6))
plt.imshow(corr_matrix, cmap='coolwarm')
plt.colorbar()

plt.xticks(range(len(corr_cols)), corr_cols, rotation=45)
plt.yticks(range(len(corr_cols)), corr_cols)

plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Top Employees

# %%
top10= df.nlargest(10,'productivity_index')
plt.bar(top10['full_name'],top10['productivity_index'])
plt.xticks(rotation = 90)
plt.show()
